# %%
import csv
import pandas as pd
import re
from collections import Counter

# %%
# Load the CSV file
data = pd.read_csv('Place Detail - Hasil_Ekstraksi(One Keyword) + Reranked.csv')

# Extract the keywords from the 'Keywords' column
keywords = data['One_Keywords'].tolist()

# Convert keywords to strings
keywords = [str(keyword) for keyword in keywords]

# Count the occurrences of each word
word_counts = Counter([re.sub(r'[^\w\s]', '', word) for keyword in keywords for word in keyword.split()])

# Sort the word counts in descending order
sorted_counts = sorted(word_counts.items(), key=lambda x: x[1], reverse=True)

# Print the sorted word counts
for word, count in sorted_counts:
    print(f"{word}: {count}")
# Out:
# coffee: 664
# place: 476
# menu: 406
# cafe: 359
# affordable: 295
# wifi: 270
# comfortable: 236
# cozy: 232
# friendly: 220
# malang: 215
# cheap: 181
# prices: 179
# really: 171
# good: 153
# delicious: 121
# great: 109
# especially: 106
# enjoy: 105
# nice: 104
# drinks: 98
# ambience: 97
# menus: 97
# parking: 92
# atmosphere: 92
# recommended: 92
# shop: 91
# try: 91
# hangout: 87
# cool: 81
# drink: 75
# service: 74
# price: 73
# rice: 71
# students: 66
# stmj: 62
# definitely: 57
# ok: 56
# like: 56
# food: 56
# maybe: 53
# noodles: 51
# taste: 47
# hang: 44
# relaxing: 42
# tea: 39
# fresh: 38
# quality: 37
# bad: 37
# cafes: 35
# vibes: 34
# strategic: 33
# restaurant: 32
# snacks: 31
# coffe: 31
# beverages: 30
# boarding: 30
# chicken: 30
# sure: 30
# hanging: 30
# awesome: 30
# expensive: 30
# average: 29
# fun: 29
# available: 28
# worth: 27
# assignments: 27
# warkop: 27
# sweet: 26
# ice: 26
# kopi: 25
# excellent: 25
# tasty: 25
# interesting: 24
# joss: 24
# ...

# %%
# Save the word counts to a CSV file
output_file = 'Keyword_Count.csv'
with open(output_file, 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Word', 'Count'])
    writer.writerows(sorted_counts)
